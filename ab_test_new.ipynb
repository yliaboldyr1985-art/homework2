# %% [markdown]
# ## A/B - тестирование
#
#
# Внутри увидите пример как формируются результаты по аб-тестированию. Прочтите сначала его, затем приступайте к выполнению задания.
#
# В папке присутствует файл ab_test_ensembles.csv , который содержит реальные данные ab теста. Вам необходимо провести стандартный пайплайн, начав с ознакомления данных до вывода отчета. Условие гипотезы такое же как и в примере, нам необходимо нашим новым вариантом увеличить коэффициент конверсии на 2%, коэффициенты конверсии одинаковы с файлом из примера (плюс/минус) поэтому с этим проблем быть не должно. Условия гипотез теже.
#
# В A/B тесте было два варианта работы сервиса - standard и svm_ensemble_v_1_22, где работала модель классификации пользователей.
#
# Ответьте на 2 вопроса:
#
# 1. Стоит ли нам оставить старый вариант работы или заменить на вариант svm_ensemble_v_1_22 (используем всю выборку 200к+ записей)
# 2. Так же посчитайте вывод для типа пользователей (user_type) стоит ли для новых/старых пользователей (new/registered user) оставить старый / новый вариант работы (разделяем всю выборку 200к+ записей на группы)
#
# Также необходимо провести небольшое EDA по представленному датасету, нарисовать два графика на ваш вкус.
#
# ---
#
# **Баллы могут быть снижены** за качество кода - старайтесь чтобы код был максимально лаконичным. Названия переменных (если они используются) должны отражать максимальную ее сущность.
#
# **Комментарии по сдаче практического задания**:
# 1. Залить в репу на github в папку module_2/ab_test_inference
# 2. Ссылку на репо отправлять мне на почту alexadevv@gmail.com не позднее дедлайна.
# 3. Тема письма: Домашнее задание по модулю 2 <Фамилия Имя>
# 4. После дедлайна, неотправленные на почту задания, оцениваются максимум в 7 баллов.

# %%
pip install statsmodels matplotlib
# Out:
# Collecting statsmodels
#   Using cached statsmodels-0.14.6-cp314-cp314-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: matplotlib in c:\users\asus\appdata\local\programs\python\python314\lib\site-packages (3.10.8)
# Requirement already satisfied: numpy<3,>=1.22.3 in c:\users\asus\appdata\local\programs\python\python314\lib\site-packages (from statsmodels) (2.3.5)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\asus\appdata\local\programs\python\python314\lib\site-packages (from statsmodels) (1.16.3)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\asus\appdata\local\programs\python\python314\lib\site-packages (from statsmodels) (2.3.3)
# Collecting patsy>=0.5.6 (from statsmodels)
#   Downloading patsy-1.0.2-py2.py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: packaging>=21.3 in c:\users\asus\appdata\local\programs\python\python314\lib\site-packages (from statsmodels) (25.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\asus\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\asus\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\asus\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\asus\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\asus\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\asus\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\asus\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\appdata\local\programs\python\python314\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\asus\appdata\local\programs\python\python314\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\asus\appdata\local\programs\python\python314\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading statsmodels-0.14.6-cp314-cp314-win_amd64.whl (9.6 MB)
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.6 MB 1.1 MB/s eta 0:00:09
#    --- ------------------------------------ 0.8/9.6 MB 1.0 MB/s eta 0:00:09
#    --- ------------------------------------ 0.8/9.6 MB 1.0 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.0/9.6 MB 893.4 kB/s eta 0:00:10
#    ---- ----------------------------------- 1.0/9.6 MB 893.4 kB/s eta 0:00:10
#    ----- ---------------------------------- 1.3/9.6 MB 738.0 kB/s eta 0:00:12
#    ----- ---------------------------------- 1.3/9.6 MB 738.0 kB/s eta 0:00:12
#    ----- ---------------------------------- 1.3/9.6 MB 738.0 kB/s eta 0:00:12
#    ----- ---------------------------------- 1.3/9.6 MB 738.0 kB/s eta 0:00:12
#    ------ --------------------------------- 1.6/9.6 MB 577.0 kB/s eta 0:00:14
#    ------ --------------------------------- 1.6/9.6 MB 577.0 kB/s eta 0:00:14
#    ------ --------------------------------- 1.6/9.6 MB 577.0 kB/s eta 0:00:14
#    ------- -------------------------------- 1.8/9.6 MB 575.4 kB/s eta 0:00:14
#    ------- -------------------------------- 1.8/9.6 MB 575.4 kB/s eta 0:00:14
#    -------- ------------------------------- 2.1/9.6 MB 575.6 kB/s eta 0:00:14
#    -------- ------------------------------- 2.1/9.6 MB 575.6 kB/s eta 0:00:14
#    -------- ------------------------------- 2.1/9.6 MB 575.6 kB/s eta 0:00:14
#    --------- ------------------------------ 2.4/9.6 MB 555.4 kB/s eta 0:00:14
#    ---------- ----------------------------- 2.6/9.6 MB 577.3 kB/s eta 0:00:13
#    ---------- ----------------------------- 2.6/9.6 MB 577.3 kB/s eta 0:00:13
#    ------------ --------------------------- 2.9/9.6 MB 583.6 kB/s eta 0:00:12
#    ------------- -------------------------- 3.1/9.6 MB 612.3 kB/s eta 0:00:11
#    -------------- ------------------------- 3.4/9.6 MB 640.4 kB/s eta 0:00:10
#    -------------- ------------------------- 3.4/9.6 MB 640.4 kB/s eta 0:00:10
#    -------------- ------------------------- 3.4/9.6 MB 640.4 kB/s eta 0:00:10
#    --------------- ------------------------ 3.7/9.6 MB 610.0 kB/s eta 0:00:10
#    --------------- ------------------------ 3.7/9.6 MB 610.0 kB/s eta 0:00:10
#    ---------------- ----------------------- 3.9/9.6 MB 617.2 kB/s eta 0:00:10
#    ----------------- ---------------------- 4.2/9.6 MB 630.8 kB/s eta 0:00:09
#    ------------------ --------------------- 4.5/9.6 MB 641.6 kB/s eta 0:00:08
#    ------------------ --------------------- 4.5/9.6 MB 641.6 kB/s eta 0:00:08
#    ------------------- -------------------- 4.7/9.6 MB 656.8 kB/s eta 0:00:08
#    -------------------- ------------------- 5.0/9.6 MB 667.4 kB/s eta 0:00:07
#    --------------------- ------------------ 5.2/9.6 MB 677.2 kB/s eta 0:00:07
#    --------------------- ------------------ 5.2/9.6 MB 677.2 kB/s eta 0:00:07
#    ---------------------- ----------------- 5.5/9.6 MB 684.2 kB/s eta 0:00:06
#    ------------------------ --------------- 5.8/9.6 MB 689.1 kB/s eta 0:00:06
#    ------------------------ --------------- 5.8/9.6 MB 689.1 kB/s eta 0:00:06
#    ------------------------- -------------- 6.0/9.6 MB 684.5 kB/s eta 0:00:06
#    ------------------------- -------------- 6.0/9.6 MB 684.5 kB/s eta 0:00:06
#    -------------------------- ------------- 6.3/9.6 MB 690.5 kB/s eta 0:00:05
#    --------------------------- ------------ 6.6/9.6 MB 701.4 kB/s eta 0:00:05
#    ----------------------------- ---------- 7.1/9.6 MB 729.5 kB/s eta 0:00:04
#    ------------------------------ --------- 7.3/9.6 MB 744.9 kB/s eta 0:00:04
#    ------------------------------- -------- 7.6/9.6 MB 760.0 kB/s eta 0:00:03
#    -------------------------------- ------- 7.9/9.6 MB 774.8 kB/s eta 0:00:03
#    --------------------------------- ------ 8.1/9.6 MB 779.5 kB/s eta 0:00:02
#    ---------------------------------- ----- 8.4/9.6 MB 791.6 kB/s eta 0:00:02
#    ------------------------------------- -- 8.9/9.6 MB 819.8 kB/s eta 0:00:01
#    -------------------------------------- - 9.2/9.6 MB 833.3 kB/s eta 0:00:01
#    ---------------------------------------  9.4/9.6 MB 844.0 kB/s eta 0:00:01
#    ---------------------------------------- 9.6/9.6 MB 845.2 kB/s  0:00:11
# Downloading patsy-1.0.2-py2.py3-none-any.whl (233 kB)
# Installing collected packages: patsy, statsmodels
#
#    ---------------------------------------- 0/2 [patsy]
#    ---------------------------------------- 0/2 [patsy]
#    ---------------------------------------- 0/2 [patsy]
#    ---------------------------------------- 0/2 [patsy]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    ---------------------------------------- 2/2 [statsmodels]
#
# Successfully installed patsy-1.0.2 statsmodels-0.14.6
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import statsmodels.stats.api as sms
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from math import ceil

# %% [markdown]
# ## Дизайн эксперимента
# Определим необходимый размер выборки для проведения нашего эксперимента и убедимся в том, что он достатчен для нашего исследования.

# %%
effect_size = sms.proportion_effectsize(0.13, 0.15)
required_n = sms.NormalIndPower().solve_power(effect_size, power=0.8, alpha=0.05, ratio=1)
required_n = ceil(required_n)
print(F"Для каждой группы нам необходимо не меньше {required_n} наблюдений")
# Out:
# Для каждой группы нам необходимо не меньше 4720 наблюдений

# %% [markdown]
# ## Сбор данных и подготовка

# %%
df = pd.read_csv('./ab_test_ensembles.csv')
df.head(10)
# Out:
#                                 user_id                   timestamp  \
# 0  9109b0dc-d393-497f-8d63-ba9a25dd16b4  2022-05-21 22:11:48.556739
# 1  2430c3d2-f75b-4b31-8271-51b6a76c2652  2022-05-12 08:01:45.159739
# 2  44788c4e-8dd2-4fad-b986-75e76f4adb64  2022-05-11 16:55:06.154213
# 3  4699a417-506d-41b8-a354-6af6ad576963  2022-05-08 18:28:03.143765
# 4  304b0d28-bcdf-401a-9dff-66230d3ba0bc  2022-05-21 01:52:26.210827
# 5  426f77eb-8739-43b6-999c-aecd14d9f346  2022-05-10 15:20:49.083499
# 6  aa9d93c5-a18f-444a-a522-7e7145835362  2022-05-19 03:26:46.940749
# 7  de214e30-9b8d-44cf-87b1-16917f3e1c89  2022-05-17 01:48:29.539573
# 8  070f398e-e6bf-43e7-88bb-37eff2cb9212  2022-05-04 17:58:08.979471
# 9  9cff0b7e-d42b-4508-9fbe-a4e74f7f29c5  2022-05-15 18:11:06.610965
#
#        group             variants  converted        location age_group  \
# 0    control             standard          0  United Kingdom     18-25
# 1    control             standard          0  United Kingdom     42-49
# 2  treatment  svm_ensemble_v_1_22          0  United Kingdom     26-33
# 3  treatment  svm_ensemble_v_1_22          0  United Kingdom     42-49
# 4    control             standard          1  United Kingdom     42-49
# 5    control             standard          0  United Kingdom     42-49
# 6  treatment  svm_ensemble_v_1_22          1  United Kingdom     26-33
# 7    control             standard          0  United Kingdom     18-25
# 8  treatment  svm_ensemble_v_1_22          1  United Kingdom     18-25
# 9  treatment  svm_ensemble_v_1_22          1  United Kingdom     26-33
#
#          user_type
# 0  registered_user
# 1  registered_user
# 2         new_user
# 3  registered_user
# 4  registered_user
# 5  registered_user
# 6  registered_user
# 7  registered_user
# 8         new_user
# 9         new_user

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 294478 entries, 0 to 294477
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   user_id    294478 non-null  object
#  1   timestamp  294478 non-null  object
#  2   group      294478 non-null  object
#  3   variants   294478 non-null  object
#  4   converted  294478 non-null  int64
#  5   location   294478 non-null  object
#  6   age_group  294478 non-null  object
#  7   user_type  294478 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 18.0+ MB

# %%
df.user_type.value_counts()
# Out:
# user_type
# registered_user    147240
# new_user           147238
# Name: count, dtype: int64

# %%
df.group.value_counts(normalize=True)
# Out:
# group
# treatment    0.500126
# control      0.499874
# Name: proportion, dtype: float64

# %%
#проверим, сколько у нас значений для каждой групп: control - treatment, убедимся, что эти признаки находятся в достаточной количестве т.е больше 4720
df['group'].value_counts()
sessions = df['user_id'].value_counts(ascending=False)
duplicate_users = sessions[sessions > 1].count()
print(f"У нас имеются {duplicate_users} пользователей, которые не уникальны в нашей выборке.")
# Out:
# У нас имеются 0 пользователей, которые не уникальны в нашей выборке.

# %%
# Убедимся, что контрольная и испытуемая группы пользуются обоими вариантами работы сервиса
pd.crosstab(df['group'], df['variants'])
# Out:
# variants   standard  svm_ensemble_v_1_22
# group
# control      145274                 1928
# treatment      1965               145311

# %%
#проверим, сколько у нас значений для каждой групп: control - treatment, убедимся, что эти признаки находятся в достаточной количестве т.е больше 4720
df['group'].value_counts()
# Out:
# group
# treatment    147276
# control      147202
# Name: count, dtype: int64

# %%
#Количество пользователей в контрольной и опытной группах разное, 
#поэтому сформируем одинаковое максимально  количество пользователей в каждой из групп случайным образом, учитывая необходимость 
#использовать всю выборку
control_sample = df[df['group'] == 'control'].sample(147202, random_state=42)
treatment_sample = df[df['group'] == 'treatment'].sample(147202, random_state=42)
# Сформируем общую случайную выборку
ab_df = pd.concat([control_sample, treatment_sample], axis=0)
ab_df.reset_index(drop=True, inplace=True)
ab_df.head()
# Out:
#                                 user_id                   timestamp    group  \
# 0  bcf8452b-3056-4d45-994f-5f286fd9869a  2022-05-18 04:44:18.590293  control
# 1  3c827a98-0868-4ce5-ac31-8195e243af37  2022-05-14 05:22:43.771772  control
# 2  71c72bb9-13d9-4755-b398-b2c5d8b1c4d6  2022-05-23 08:52:53.050325  control
# 3  654ee878-b0c5-4223-b9fb-995ca3d2eaf1  2022-05-07 23:27:09.109877  control
# 4  1e044366-7e86-4d92-bba7-3afaa6f887f8  2022-05-20 14:26:10.133979  control
#
#    variants  converted        location age_group        user_type
# 0  standard          0  United Kingdom     42-49         new_user
# 1  standard          0  United Kingdom     50-57         new_user
# 2  standard          0  United Kingdom     34-41         new_user
# 3  standard          0  United Kingdom     26-33  registered_user
# 4  standard          0  United Kingdom     42-49         new_user

# %%
ab_df.info() все user_id уникальны, пропущенных знаячений нет
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 294404 entries, 0 to 294403
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   user_id    294404 non-null  object
#  1   timestamp  294404 non-null  object
#  2   group      294404 non-null  object
#  3   variants   294404 non-null  object
#  4   converted  294404 non-null  int64
#  5   location   294404 non-null  object
#  6   age_group  294404 non-null  object
#  7   user_type  294404 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 18.0+ MB

# %%
ab_df.group.value_counts(normalize=True)#убедимся, что количество одинаково
# Out:
# group
# control      0.5
# treatment    0.5
# Name: proportion, dtype: float64

# %%
ab_df.isnull().sum()#убед
# Out:
# user_id      0
# timestamp    0
# group        0
# variants     0
# converted    0
# location     0
# age_group    0
# user_type    0
# dtype: int64

# %%
ab_df.converted.value_counts()
# Out:
# converted
# 0    259177
# 1     35227
# Name: count, dtype: int64

# %%
ab_df.age_group.value_counts()
# Out:
# age_group
# 26-33    49261
# 50-57    49215
# 58+      49173
# 42-49    49108
# 34-41    48883
# 18-25    48764
# Name: count, dtype: int64

# %%
ab_df.user_type.value_counts()
# Out:
# user_type
# new_user           147202
# registered_user    147202
# Name: count, dtype: int64

# %% [markdown]
# ## Визуализация результатов эксперимента. Рассчитаем выборочные статистики: стандартное отклонение sdt, среднее mean и ошибку среднего sem  чтобы понять каково распределение данных и как выглядят наши выборки

# %%
conversion_rates = ab_df.groupby('group')['converted']
std_proportion = lambda x: np.std(x, ddof=0)
# Стандартная ошибка для сформированной выборки
se_proportion = lambda x: stats.sem(x, ddof=0)

conversion_rates = conversion_rates.agg([np.mean, std_proportion, se_proportion]).rename(columns={'mean':'CR mean', '<lambda_0>':'CR std', '<lambda_1>':'CR se'})
conversion_rates
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_21100\1611041459.py:6: FutureWarning: The provided callable <function mean at 0x0000021FC9019A60> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   conversion_rates = conversion_rates.agg([np.mean, std_proportion, se_proportion]).rename(columns={'mean':'CR mean', '<lambda_0>':'CR std', '<lambda_1>':'CR se'})
#             CR mean    CR std     CR se
# group
# control    0.120399  0.325428  0.000848
# treatment  0.118911  0.323684  0.000844

# %%
plt.figure(figsize=(8,6));
sns.barplot(x=ab_df['group'], y=ab_df['converted'], palette="pastel", errorbar=('ci', False))
plt.ylim(0, 0.17);
plt.title('Conversion rate for ab', pad=20)
plt.xlabel('Group', labelpad=15);
plt.ylabel('Converted (proportion)', labelpad=15);
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_29604\70975740.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=ab_df['group'], y=ab_df['converted'], palette="pastel", errorbar=('ci', False))

# %%
Н0-гипотеза - работаем со  сервисом и ничего не меняем, Н1 - заменяем на новый .

# %% [markdown]
# ## Тестирование гипотезы
# По результатм теста мы должны ответиить на воспрос: действительно ли разница статистически значимой. Поскольку наша выборка гораздо больше 30, будем использовать нормальную аппроксимацию - рассчитаем  p-статистику (Z-test).

# %%
from statsmodels.stats.proportion import proportions_ztest, proportion_confint

control_results = ab_df[ab_df['group'] == 'control']['converted']
treatment_results = ab_df[ab_df['group'] == 'treatment']['converted']

n_con = control_results.count()
n_treat = treatment_results.count()
successes = [control_results.sum(), treatment_results.sum()]
nobs = [n_con, n_treat]

z_stat, pval = proportions_ztest(successes, nobs=nobs)
(lower_con, lower_treat), (upper_con, upper_treat) = proportion_confint(successes, nobs=nobs, alpha=0.05)

print(f'Z-statistic: {z_stat:.2f}')
print(f'p-value: {pval:.3f}')
print(f'CI 95% for control group: [{lower_con:.3f}, {upper_con:.3f}]')
print(f'CI 95% for treatment group: [{lower_treat:.3f}, {upper_treat:.3f}]')
# Out:
# Z-statistic: 1.24
# p-value: 0.214
# CI 95% for control group: [0.119, 0.122]
# CI 95% for treatment group: [0.117, 0.121]

# %%
Так как наше p-значение = 0.214 что является высоким показателем по сравнению с выбранной альфой 0.05, то согласно статистическому выводу, мы не
можем отклонить нулевую гипотезу H0, что означает наш новый сервис -  svm_ensemble_v_1_22 никак статистически значимо не влияет на уровень конверсии
и повышение уровня конверсии - это случайность.

Доверительный интервал для испытуемой группы [0.117, 0.121] или 11% и 12% соответственно:

Он включает наш baseline
Он не достигает нашей цели 15%
Мы можем интерпретировать это как - наиболее вероятно, что реальный уровень конверсии сайта с новым дизайном будет близок к baseline чем к 15%,
который мы определили по нашей цели.
    Таким образом у нас два варианта:
    - Можно создать новую версию сервиса (потратить время, деньги) и опять протестировать, надо решать стоят ли затраты на новую версию 2% улучшения 
    -Ничего не менять.

# %% [markdown]
#  ## Посчитаем вывод для типа пользователей (user_type)
# стоит ли для новых/старых пользователей (new/registered user) оставить старый / новый вариант работы
# для этого разделим df на 2 части по user_type: df_new - для новых пользователей и df-reg - для зарегистрированных ранее

# %%
pd.crosstab(ab_df['group'], ab_df['user_type'])
# Out:
# user_type  new_user  registered_user
# group
# control       73750            73452
# treatment     73452            73750

# %%
df_new = ab_df[ab_df.user_type =='new_user']
df_reg = ab_df[ab_df.user_type =='registered_user']
df_new.info()
df_reg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 147202 entries, 0 to 294402
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   user_id    147202 non-null  object
#  1   timestamp  147202 non-null  object
#  2   group      147202 non-null  object
#  3   variants   147202 non-null  object
#  4   converted  147202 non-null  int64
#  5   location   147202 non-null  object
#  6   age_group  147202 non-null  object
#  7   user_type  147202 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 10.1+ MB
# <class 'pandas.core.frame.DataFrame'>
# Index: 147202 entries, 3 to 294403
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   user_id    147202 non-null  object
#  1   timestamp  147202 non-null  object
#  2   group      147202 non-null  object
#  3   variants   147202 non-null  object
#  4   converted  147202 non-null  int64
#  5   location   147202 non-null  object
#  6   age_group  147202 non-null  object
#  7   user_type  147202 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 10.1+ MB

# %%
df_new.group.value_counts(), df_reg.group.value_counts()
# Out:
# (group
#  control      73750
#  treatment    73452
#  Name: count, dtype: int64,
#  group
#  treatment    73750
#  control      73452
#  Name: count, dtype: int64)

# %% [markdown]
# ## Cформируем 2 датасета с одинаковым количеством control n treatment ab_df_new - для новых пользователей, ab_df_reg  - для уже зарегистрированных ранее

# %%
#Количество пользователей в контрольной и опытной группах разное, 
#поэтому сформируем одинаковое максимально  количество пользователей в каждой из групп случайным образом, учитывая необходимость 
#использовать всю выборку
control_sample_new = df_new[df_new['group'] == 'control'].sample(73452, random_state=41)
treatment_sample_new = df_new[df_new['group'] == 'treatment'].sample(73452, random_state=41)
# Сформируем общую случайную выборку
ab_df_new = pd.concat([control_sample_new, treatment_sample_new], axis=0)
ab_df_new.reset_index(drop=True, inplace=True)
ab_df_new.head()
# Out:
#                                 user_id                   timestamp    group  \
# 0  f0774bc6-ddbe-4eba-b5b1-15ebdd845c98  2022-05-18 18:52:11.979532  control
# 1  38c283f9-aabb-4b43-a6c1-64644d9cf78b  2022-05-14 19:07:35.309109  control
# 2  5640d1da-f9b9-4527-b2e7-fce7ca522ed4  2022-05-14 21:20:47.944392  control
# 3  8a0ae22f-6103-47b5-acbb-e666cb9ef437  2022-05-14 20:02:32.788308  control
# 4  de4c9608-9f5c-4cbe-8660-5c55ad40ef23  2022-05-10 03:48:15.166569  control
#
#    variants  converted        location age_group user_type
# 0  standard          0  United Kingdom     50-57  new_user
# 1  standard          0  United Kingdom     34-41  new_user
# 2  standard          0  United Kingdom     18-25  new_user
# 3  standard          0  United Kingdom     34-41  new_user
# 4  standard          0  United Kingdom     42-49  new_user

# %% [markdown]
# ## Построим два графика для наглядности для новых и уже зарегистрированных пользователей

# %%
plt.figure(figsize=(8,6));
sns.barplot(x=ab_df_new['group'], y=ab_df_new['converted'], errorbar=('ci', False))
plt.ylim(0, 0.17);
plt.title('Conversion rate for new_user', pad=20)
plt.xlabel('Group', labelpad=15);
plt.ylabel('Converted (proportion)', labelpad=15);
plt.show()

# %% [markdown]
# ## Тестирование гипотезы для новых пользователей

# %%
from statsmodels.stats.proportion import proportions_ztest, proportion_confint

control_results_new = ab_df_new[ab_df_new['group'] == 'control']['converted']
treatment_results_new = ab_df_new[ab_df_new['group'] == 'treatment']['converted']

n_con_new = control_results_new.count()
n_treat_new = treatment_results_new.count()
successes = [control_results_new.sum(), treatment_results_new.sum()]
nobs = [n_con_new, n_treat_new]

z_stat, pval = proportions_ztest(successes, nobs=nobs)
(lower_con, lower_treat), (upper_con, upper_treat) = proportion_confint(successes, nobs=nobs, alpha=0.05)

print(f'Z-statistic: {z_stat:.2f}')
print(f'p-value: {pval:.3f}')
print(f'CI 95% for control group: [{lower_con:.3f}, {upper_con:.3f}]')
print(f'CI 95% for treatment group: [{lower_treat:.3f}, {upper_treat:.3f}]')
# Out:
# Z-statistic: 1.89
# p-value: 0.058
# CI 95% for control group: [0.118, 0.123]
# CI 95% for treatment group: [0.115, 0.120]

# %%
Так как наше p-значение = 0.058 , что близко к нашей альфе 0.05, но все-таки большее, поэтому  то согласно статистическому выводу, мы не
можем отклонить нулевую гипотезу H0, что означает наш новый сервис -  svm_ensemble_v_1_22 никак статистически значимо не влияет на уровень конверсии
и повышение уровня конверсии - это случайность. Но, наш результат относится к пограничному состоянию, что указывает на наличие слабой тенденции , 
требующей дальнейшего изучения или увеличения выборки 

Доверительный интервал для испытуемой группы [0.115, 0.120] или 11.5% и 12% соответственно:

Он включает наш baseline
Он не достигает нашей цели 15%
Мы можем интерпретировать это как - наиболее вероятно, что реальный уровень конверсии сайта с новым дизайном будет близок к baseline чем к 15%,
который мы определили по нашей цели.
    Таким образом у нас два варианта:
    - Можно создать новую версию сервиса и опять протестировать на новой , большей выборке
    -Ничего не менять.

# %%
#Количество пользователей в контрольной и опытной группах разное, 
#поэтому сформируем одинаковое максимально  количество пользователей в каждой из групп случайным образом, учитывая необходимость 
#использовать всю выборку
control_sample_reg = df_reg[df_reg['group'] == 'control'].sample(73452, random_state=41)
treatment_sample_reg = df_reg[df_reg['group'] == 'treatment'].sample(73452, random_state=41)
# Сформируем общую случайную выборку
ab_df_reg = pd.concat([control_sample_reg, treatment_sample_reg], axis=0)
ab_df_reg.reset_index(drop=True, inplace=True)
ab_df_reg.head()
# Out:
#                                 user_id                   timestamp    group  \
# 0  27f1b5cf-783c-4433-9917-f800f806dd1c  2022-05-08 04:55:53.122889  control
# 1  76333537-243f-47bb-9647-306ecb477607  2022-05-10 10:11:38.758252  control
# 2  b6079e07-3f7e-439f-ae25-30a1a4dba05c  2022-05-06 12:42:00.265799  control
# 3  916900fd-eaae-4769-add4-ec9e2ab05b39  2022-05-21 04:33:26.338101  control
# 4  53fd8197-b89b-485a-bf93-15010d0bd64e  2022-05-10 08:32:52.929812  control
#
#    variants  converted        location age_group        user_type
# 0  standard          0  United Kingdom     34-41  registered_user
# 1  standard          0  United Kingdom     34-41  registered_user
# 2  standard          0  United Kingdom     50-57  registered_user
# 3  standard          0  United Kingdom     50-57  registered_user
# 4  standard          0  United Kingdom     26-33  registered_user

# %%
plt.figure(figsize=(8,6));
sns.barplot(x=ab_df_reg['group'], y=ab_df_reg['converted'], palette="magma", errorbar=('ci', False))
plt.ylim(0, 0.17);
plt.title('Conversion rate for registred_user', pad=20)
plt.xlabel('Group', labelpad=15);
plt.ylabel('Converted (proportion)', labelpad=15);
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_11072\172909449.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=ab_df_reg['group'], y=ab_df_reg['converted'], palette="magma", errorbar=('ci', False))

# %%
from statsmodels.stats.proportion import proportions_ztest, proportion_confint

control_results_reg = ab_df_reg[ab_df_reg['group'] == 'control']['converted']
treatment_results_reg = ab_df_reg[ab_df_reg['group'] == 'treatment']['converted']

n_con_reg = control_results_reg.count()
n_treat_reg = treatment_results_reg.count()
successes = [control_results_reg.sum(), treatment_results_reg.sum()]
nobs = [n_con_reg, n_treat_reg]

z_stat, pval = proportions_ztest(successes, nobs=nobs)
(lower_con, lower_treat), (upper_con, upper_treat) = proportion_confint(successes, nobs=nobs, alpha=0.05)

print(f'Z-statistic: {z_stat:.2f}')
print(f'p-value: {pval:.3f}')
print(f'CI 95% for control group: [{lower_con:.3f}, {upper_con:.3f}]')
print(f'CI 95% for treatment group: [{lower_treat:.3f}, {upper_treat:.3f}]')
# Out:
# Z-statistic: -0.15
# p-value: 0.879
# CI 95% for control group: [0.118, 0.122]
# CI 95% for treatment group: [0.118, 0.123]

# %%
Так как наше p-значение = 0.879 , что гораздо больше нашей альфы 0.05,поэтому согласно статистическому выводу, мы не
можем отклонить нулевую гипотезу H0, что означает наш новый сервис -  svm_ensemble_v_1_22 никак статистически значимо не влияет на уровень конверсии
и повышение уровня конверсии - это случайность.

Доверительный интервал для испытуемой группы [0.118, 0.123] или 11.8% и 12% соответственно:

Он включает наш baseline
Он не достигает нашей цели 15%
Мы можем интерпретировать это как - наиболее вероятно, что реальный уровень конверсии сайта с новым дизайном будет близок к baseline чем к 15%,
который мы определили по нашей цели.
    Таким образом, в данном случае лучше Ничего не менять для регистрированных пользователей.
